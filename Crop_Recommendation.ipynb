# %% [markdown]
# This cell imports the necessary libraries for data manipulation, visualization, and machine learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as fx
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score
import plotly.graph_objects as go

# %% [markdown]
# This function creates a Plotly scatter plot comparing actual and predicted values over their index.

# %%
def plot_actual_vs_predicted(y_test, y_pred, title="Actual vs Predicted over Index"):
    # Create DataFrame for plotting
    df_plot = pd.DataFrame({"Actual": y_test, "Predicted": y_pred})

    # Create figure
    fig = go.Figure()

    # Actual values trace
    fig.add_trace(go.Scatter(
    x=df_plot.index,
    y=df_plot["Actual"],
    mode='markers',
    name='Actual',
    marker=dict(color='blue', opacity=0.9, size=10)
    ))

    fig.add_trace(go.Scatter(
        x=df_plot.index,
        y=df_plot["Predicted"],
        mode='markers',
        name='Predicted',
        marker=dict(color='red', opacity=0.7)
    ))

    # Layout
    fig.update_layout(
        title="Actual vs Predicted over Index",
        xaxis_title="Index",
        yaxis_title="Value",
        template="plotly_dark",
        legend=dict(x=0.85, y=1),
        height = 800,
    )
    return fig

# %% [markdown]
# This function generates a Plotly scatter plot showing actual vs. predicted values with a diagonal line representing perfect prediction.

# %%
def scatter_actual_vs_predicted(y_test, y_pred, title="Actual vs Predicted (Plotly)"):
    # Create DataFrame for plotting
    df_plot = pd.DataFrame({"Actual": y_test, "Predicted": y_pred})

    # Create scatter plot
    fig = px.scatter(
        df_plot,
        x="Actual",
        y="Predicted",
        title=title,
        labels={"Actual": "Actual Values", "Predicted": "Predicted Values"},
        opacity=0.7
    )

    # Add perfect fit line (y = x)
    min_val = min(df_plot["Actual"].min(), df_plot["Predicted"].min())
    max_val = max(df_plot["Actual"].max(), df_plot["Predicted"].max())

    fig.add_shape(
        type="line",
        x0=min_val, y0=min_val,
        x1=max_val, y1=max_val,
        line=dict(color="red", dash="dash")
    )
    return fig

# %% [markdown]
# This cell loads the dataset from a CSV file into a pandas DataFrame and displays the first few rows.

# %%
df = pd.read_csv("/content/crop.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# This cell provides a concise summary of the DataFrame, including the data types and non-null counts for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %% [markdown]
# This cell generates descriptive statistics of the numerical columns in the DataFrame, such as count, mean, standard deviation, min, and max values.

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %% [markdown]
# This cell checks for missing values in each column of the DataFrame and displays the count of null values.

# %%
df.isna().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# This cell initializes an OrdinalEncoder object and creates a copy of the original DataFrame for encoding.

# %%
od = OrdinalEncoder()
df_convt = df.copy()

# %% [markdown]
# This cell identifies and extracts the names of the categorical columns in the DataFrame (columns with 'object' dtype).

# %%
categorical_col = df_convt.select_dtypes(include="object").columns
categorical_col
# Out:
# Index(['label'], dtype='object')

# %% [markdown]
# This cell applies Ordinal Encoding to the categorical columns in the copied DataFrame and converts the encoded values to integers.

# %%
df_convt[categorical_col] = od.fit_transform(df[categorical_col]).astype(int)
df_convt
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536     20
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537     20
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248     20
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034     20
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340     20
# ...   ...  ..  ..          ...        ...       ...         ...    ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507      5
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610      5
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839      5
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293      5
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041      5
#
# [2200 rows x 8 columns]

# %% [markdown]
# This cell separates the features (input variables) and the target variable ('label') from the encoded DataFrame.

# %%
target = 'label'
features = df_convt.drop(target, axis=1)
target = df_convt[target]

features, target
# Out:
# (        N   P   K  temperature   humidity        ph    rainfall
#  0      90  42  43    20.879744  82.002744  6.502985  202.935536
#  1      85  58  41    21.770462  80.319644  7.038096  226.655537
#  2      60  55  44    23.004459  82.320763  7.840207  263.964248
#  3      74  35  40    26.491096  80.158363  6.980401  242.864034
#  4      78  42  42    20.130175  81.604873  7.628473  262.717340
#  ...   ...  ..  ..          ...        ...       ...         ...
#  2195  107  34  32    26.774637  66.413269  6.780064  177.774507
#  2196   99  15  27    27.417112  56.636362  6.086922  127.924610
#  2197  118  33  30    24.131797  67.225123  6.362608  173.322839
#  2198  117  32  34    26.272418  52.127394  6.758793  127.175293
#  2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
#  [2200 rows x 7 columns],
#  0       20
#  1       20
#  2       20
#  3       20
#  4       20
#          ..
#  2195     5
#  2196     5
#  2197     5
#  2198     5
#  2199     5
#  Name: label, Length: 2200, dtype: int64)

# %% [markdown]
# This cell splits the features and target variables into training and testing sets for model building and evaluation.

# %%
x_train, x_test, y_train, y_test = train_test_split(features,target,test_size=0.2,random_state=42,shuffle=True)

# %% [markdown]
# This cell imports the Linear Regression and Logistic Regression models from the scikit-learn library.

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression

# %% [markdown]
# This cell trains a Linear Regression model on the training data and evaluates its performance using various regression metrics.

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)
mse_lr = mean_squared_error(y_test,y_pred)
rmse_lr = np.sqrt(mse_lr)
r2_lr = r2_score(y_test,y_pred)
mae_lr = mean_absolute_error(y_test,y_pred)
ev_lr = explained_variance_score(y_test,y_pred)


print(f"\nModel: Linear Regression")
print(f"R² Score: {r2_lr:.4f}")
print(f"Mean Absolute Error: {mae_lr:.4f}")
print(f"Explained Variance Score: {ev_lr:.4f}")
print(f"Root Mean Squared Error: {rmse_lr:.4f}")
# Out:
# Model: Linear Regression
# R² Score: 0.2563
# Mean Absolute Error: 4.4335
# Explained Variance Score: 0.2580
# Root Mean Squared Error: 5.6102

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the Linear Regression model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e75307d-cc5a-4ff9-990e-fadb896815e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e75307d-cc5a-4ff9-990e-fadb896815e6")) {                    Plotly.newPlot(                        "6e75307d-cc5a-4ff9-990e-fadb896815e6",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[13.704625412927502,14.103436212865002,10.56637707540267,10.993888326281427,3.9217962513705356,15.014613874226749,2.8525247427993214,11.9609771688391,13.653254281340786,9.51672713961646,7.926472920682317,16.83979620918696,15.859617335826648,11.514143566771333,16.704344044632602,14.64661012357417,5.846872830737995,10.61413329703911,11.246394425519885,14.04903365363456,10.56529873320902,11.690656577181283,15.827603244651312,10.487483685430831,5.412674800658046,11.7589216317818,11.630396382274997,15.999344337401636,9.451741499897365,10.496545402918686,16.295575884648756,10.235908100416907,10.819882394915762,9.434877867253388,10.298124063539404,9.945898662325376,10.917742119157738,5.880122218688173,7.7442480470870585,9.153979234203206,10.31291257221478,13.676019287578605,9.125190831740595,11.469078683469462,12.991978335273611,9.229774513428426,9.183546212399403,17.338347727888806,13.049677398419478,9.67270229596106,8.96229436938237,10.630078184517048,5.550945365401903,13.827307438573024,10.307039814158799,8.59152451117914,9.567313929844985,4.176993990268148,8.159984358932093,9.19487204142703,12.351296320346076,17.69636962017005,9.657450938254884,16.784611259960396,11.407039005980653,10.879876677054995,16.33158487050725,10.386425825869917,14.863262661505237,10.442550408261383,12.0256173006858,16.673560024974204,11.078565230118484,5.9336059105619885,7.947165991008259,11.202557776654658,7.538565534747914,10.464439683205327,11.18140247786072,15.071286193444898,11.945497787737713,6.062419311598848,10.739433254399883,11.86702679963891,16.530765997743245,13.35322647175392,9.477762481583664,11.50270358592428,9.188244582187911,14.931079408229575,10.031568517763098,11.078108091883344,9.90566167383788,10.515953462225808,10.488854115036684,10.586212870877613,8.116175689017734,10.63527233392928,10.099552679220205,11.578440554654698,15.470634520336967,10.809280904467819,14.26327321335047,13.445914732521581,14.636063851690205,7.890009437682528,13.743452780110898,6.673999288992896,10.947078684742005,12.80127967744856,5.965289857532 ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the Linear Regression model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6a401ec0-71ce-466c-bbc5-950362259b27" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a401ec0-71ce-466c-bbc5-950362259b27")) {                    Plotly.newPlot(                        "6a401ec0-71ce-466c-bbc5-950362259b27",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell trains a Logistic Regression model on the training data and evaluates its performance using various regression metrics.

# %%
lg = LogisticRegression(max_iter=200)
lg.fit(x_train,y_train)

y_pred = lg.predict(x_test)
mse_lg = mean_squared_error(y_test,y_pred)
rmse_lg = np.sqrt(mse_lg)
r2_lg = r2_score(y_test,y_pred)
mae_lg = mean_absolute_error(y_test,y_pred)
ev_lg = explained_variance_score(y_test,y_pred)


print(f"\nModel: Logistic Regression")
print(f"R² Score: {r2_lg:.4f}")
print(f"Mean Absolute Error: {mae_lg:.4f}")
print(f"Explained Variance Score: {ev_lg:.4f}")
print(f"Root Mean Squared Error: {rmse_lg:.4f}")
# Out:
# Model: Logistic Regression
# R² Score: 0.8914
# Mean Absolute Error: 0.4182
# Explained Variance Score: 0.8916
# Root Mean Squared Error: 2.1437
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the Logistic Regression model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="baf4d4ce-4758-44a1-8376-03233b4df5ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("baf4d4ce-4758-44a1-8376-03233b4df5ce")) {                    Plotly.newPlot(                        "baf4d4ce-4758-44a1-8376-03233b4df5ce",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,6,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,13,5,7,14,5,9,6,0,1,10,21,4,10,16,17,2,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,13,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,2,14,10,21,14,2,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,11,8,12,1,17,0,3,20,18,13,14,8,19,7,13,17,11,4,6,3,1,8,4,5,12,15,0,1,18,2,16,3,21,1,0,3,5,2,16,0,4,17,21,13,20,3,19,3,17,13,0,19,3,12,3,19,21,9,14,15,21,9,15,12,8,2,3,1,10,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,6,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,20,2,14,5,1,18,18,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,2,6,17,21,13,20,4,13,14,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type" ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the Logistic Regression model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dcdd1689-ad4f-4d92-9422-aa09c854c899" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcdd1689-ad4f-4d92-9422-aa09c854c899")) {                    Plotly.newPlot(                        "dcdd1689-ad4f-4d92-9422-aa09c854c899",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell imports the KNeighborsRegressor model from the scikit-learn library and initializes it.

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=7, weights="distance")
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7, weights='distance')

# %% [markdown]
# This cell uses the trained KNN Regressor model to make predictions on the test data and evaluates its performance using various regression metrics.

# %%
y_pred = knn.predict(x_test)
mse_knn = mean_squared_error(y_test,y_pred)
rmse_knn = np.sqrt(mse_knn)
r2_knn = r2_score(y_test,y_pred)
mae_knn = mean_absolute_error(y_test,y_pred)
ev_knn = explained_variance_score(y_test,y_pred)

print(f"\nModel: KNN Regressor")
print(f"R² Score: {r2_knn:.4f}")
print(f"Mean Absolute Error: {mae_knn:.4f}")
print(f"Explained Variance Score: {ev_knn:.4f}")
print(f"Root Mean Squared Error: {rmse_knn:.4f}")
# Out:
# Model: KNN Regressor
# R² Score: 0.9584
# Mean Absolute Error: 0.3533
# Explained Variance Score: 0.9588
# Root Mean Squared Error: 1.3271

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the KNN Regressor model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dd3f13dc-3999-43b7-8223-d04b9fae53dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd3f13dc-3999-43b7-8223-d04b9fae53dc")) {                    Plotly.newPlot(                        "dd3f13dc-3999-43b7-8223-d04b9fae53dc",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[15.0,21.0,17.0,17.0,0.0,12.0,0.0,12.999999999999998,14.000000000000002,10.0,2.0,4.0,19.0,8.0,4.0,19.0,0.0,7.43617513715009,17.0,15.000000000000002,5.0,17.000000000000004,16.0,17.0,3.0,8.0,13.999999999999998,16.0,18.0,12.380960492565066,19.0,11.895708154457568,8.0,9.999999999999998,9.303626044152757,2.0,9.562095251508788,3.0000000000000004,3.0,9.000000000000002,17.0,12.0,2.827699064925024,11.000000000000002,14.000000000000004,11.000000000000002,18.0,4.0,15.000000000000002,10.999999999999998,2.0,5.000000000000002,6.999999999999998,13.999999999999998,5.0,9.000000000000002,6.000000000000001,0.0,1.0,3.1881184797768625,20.999999999999996,4.0,10.0,16.0,17.0,6.284846281421733,16.0,20.0,14.999999999999996,18.0,15.0,4.0,10.88695178613877,1.0,2.0,17.0,1.0,6.8571234834857915,20.999999999999996,16.0,5.0,3.0000000000000004,13.109596439499118,13.000000000000002,16.0,11.999999999999998,4.999999999999999,13.0,2.0,18.999999999999996,11.000000000000002,13.000000000000002,5.999999999999998,13.60985619375702,17.999999999999996,12.999999999999998,9.0,4.999999999999999,3.088330952599939,10.0,4.0,12.319107449341354,16.0,15.0,21.0,9.0,21.0,1.0,18.0,12.999999999999998,1.0,11.78949105904938,7.715087764803733,18.999999999999996,18.0,3.0,11.000000000000002,4.0,19.000000000000004,19.999999999999996,18.0,6.999999999999999,2.0,4.0,3.0,3.506679904871271,4.0,11.0,1.0,13.0,1.0,8.999999999999998,18.999999999999996,2.9999999999999996,4.0,16.0,18.0,1.0,1.0,0.0,9.0,14.999999999999998,13.999999999999996,11.904196947479573,4.0,10.388939218208321,0.0,4.0,10.183095402812171,12.999999999999998,14.000000000000002,10.000000000000002,20.999999999999996,13.999999999999998,17.239302516355572,12.122047612570777,18.0,9.000000000000002,11.0,9.506882122478547,2.999999999999999,0.0,16.0,5.999999999999999,15.377808539500592,4.0,6.999999999999999,10.0,21.000000000000004,6.999999999999999,7.000000000000001,2.0,19.0,2.9999999999999996,4.0,11.0,9.999999999999998,6.999999999999998,20.999999999999996,8.0,4.999999999999998,5.0,9.0,8.0,12.999999999999998,8.999999999999998, ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the KNN Regressor model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="efd5c6db-4357-4175-9544-27c0f7872593" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efd5c6db-4357-4175-9544-27c0f7872593")) {                    Plotly.newPlot(                        "efd5c6db-4357-4175-9544-27c0f7872593",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell imports the DecisionTreeRegressor model from the scikit-learn library and initializes it with a specified max depth.

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=7)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7)

# %% [markdown]
# This cell uses the trained Decision Tree Regressor model to make predictions on the test data and evaluates its performance using various regression metrics.

# %%
y_pred = dt.predict(x_test)
mse_dt = mean_squared_error(y_test,y_pred)
rmse_dt = np.sqrt(mse_dt)
r2_dt = r2_score(y_test,y_pred)
mae_dt = mean_absolute_error(y_test,y_pred)
ev_dt = explained_variance_score(y_test,y_pred)

print(f"\nModel: DECISION-TREE Regressor")
print(f"R² Score: {r2_dt:.4f}")
print(f"Mean Absolute Error: {mae_dt:.4f}")
print(f"Explained Variance Score: {ev_dt:.4f}")
print(f"Root Mean Squared Error: {rmse_dt:.4f}")
# Out:
# Model: DECISION-TREE Regressor
# R² Score: 0.9435
# Mean Absolute Error: 0.3761
# Explained Variance Score: 0.9435
# Root Mean Squared Error: 1.5466

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the Decision Tree Regressor model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e2a46c51-b5a2-42c6-8692-22cda1eea435" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2a46c51-b5a2-42c6-8692-22cda1eea435")) {                    Plotly.newPlot(                        "e2a46c51-b5a2-42c6-8692-22cda1eea435",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[15.0,21.0,17.0,17.0,0.0,12.05084745762712,0.0,12.05084745762712,14.0,10.0,2.0,4.0,19.0,8.0,4.0,19.0,0.0,6.27906976744186,17.0,15.0,5.0,17.0,16.0,17.0,3.0,10.454545454545455,14.0,16.0,18.0,20.0,19.0,12.05084745762712,8.0,10.0,8.0,2.0,10.454545454545455,3.0,3.0,9.0,17.0,12.05084745762712,2.0,10.894736842105264,14.0,10.894736842105264,18.0,4.0,15.0,10.894736842105264,12.05084745762712,5.0,7.0,14.0,5.0,9.0,6.0,0.0,1.0,2.0,21.0,4.0,10.0,16.0,17.0,16.333333333333332,16.0,20.0,15.0,17.82857142857143,15.0,4.0,8.0,1.0,2.0,17.0,1.0,6.0,21.0,16.0,5.0,3.0,10.454545454545455,12.05084745762712,16.0,12.05084745762712,5.0,12.05084745762712,2.0,19.0,10.894736842105264,12.05084745762712,6.27906976744186,17.0,17.82857142857143,12.05084745762712,9.0,5.0,2.0,10.0,4.0,20.0,16.0,15.0,21.0,9.0,21.0,1.0,17.82857142857143,12.05084745762712,1.0,8.0,6.27906976744186,19.0,17.82857142857143,10.894736842105264,10.894736842105264,4.0,19.0,20.0,18.0,7.0,2.0,4.0,3.0,12.05084745762712,4.0,10.894736842105264,1.0,12.05084745762712,1.0,9.0,19.0,3.0,4.0,16.0,16.333333333333332,1.0,1.0,0.0,9.0,15.0,14.0,12.05084745762712,4.0,6.27906976744186,0.0,4.0,9.0,16.333333333333332,14.0,10.0,21.0,14.0,16.333333333333332,18.0,17.82857142857143,9.0,10.894736842105264,8.0,3.0,0.0,16.0,6.27906976744186,20.0,4.0,7.0,10.0,21.0,7.0,7.0,2.0,19.0,3.0,4.0,10.894736842105264,10.0,7.0,21.0,8.0,5.0,5.0,9.0,10.454545454545455,12.05084745762712,9.0,1.0,9.0,4.0,17.0,17.0,14.0,12.05084745762712,19.0,21.0,9.0,10.894736842105264,0.0,2.0,3.0,7.0,7.0,1.0,6.27906976744186,20.0,19.0,14.0,1.0,8.0,14.0,10.894736842105264,3.0,3.0,3.0,0.0,20.0,9.0,17.0,5.0,2.0,9.0,12.05084745762712,12.05084745762712,4.0,17.0,0.0,3.0,19.0,3.0,15.0,0.0,15.0,15.0,12.05084745762712,12.05084745762712,6.0,4.0,19.0,20.0,15.0,5.0,17.0,12.05084745762712,10.894736842105264,12.05084745762712,15.0,18.0,14.0,5.0,7.0,4.0,6.27906976744186,18.0,20.0,0.0,19.0,5.0,3.0,6.27906976744186,8.0,12.05084745762712,1.0,17.0,0.0,3.0,10.454545454545455,12.05084745762712,12.05084745762712,14.0,8.0,19.0,7.0,12.05084745762712,10.45454 ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the Decision Tree Regressor model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="99bc4d1e-6aec-42a4-8fcc-1d8f5ab91346" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99bc4d1e-6aec-42a4-8fcc-1d8f5ab91346")) {                    Plotly.newPlot(                        "99bc4d1e-6aec-42a4-8fcc-1d8f5ab91346",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell defines a base estimator for the AdaBoost Regressor model, specifying the maximum depth of the Decision Tree.

# %%
base_estimator = DecisionTreeRegressor(max_depth=9)

# %% [markdown]
# This cell imports the AdaBoostRegressor model and initializes it with the base estimator, number of estimators, and learning rate. It then trains the model on the training data.

# %%
from sklearn.ensemble import AdaBoostRegressor
#ada = AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=9), learning_rate=0.5372059823454584, loss = "exponential")
ada = AdaBoostRegressor(estimator=base_estimator, n_estimators=200, learning_rate=0.5)
ada.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=9),
#                   learning_rate=0.5, n_estimators=200)

# %% [markdown]
# This cell uses the trained AdaBoost Regressor model to make predictions on the test data and evaluates its performance using various regression metrics.

# %%
y_pred = ada.predict(x_test)
mse_ada = mean_squared_error(y_test,y_pred)
rmse_ada = np.sqrt(mse_ada)
r2_ada = r2_score(y_test,y_pred)
mae_ada = mean_absolute_error(y_test,y_pred)
ev_ada = explained_variance_score(y_test,y_pred)

print(f"\nModel: ADABOOST Regressor")
print(f"R² Score: {r2_ada:.4f}")
print(f"Mean Absolute Error: {mae_ada:.4f}")
print(f"Explained Variance Score: {ev_ada:.4f}")
print(f"Root Mean Squared Error: {rmse_ada:.4f}")
# Out:
# Model: ADABOOST Regressor
# R² Score: 0.9691
# Mean Absolute Error: 0.1454
# Explained Variance Score: 0.9695
# Root Mean Squared Error: 1.1436

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the AdaBoost Regressor model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d46154b4-cdd7-4011-937d-27b634a5c236" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d46154b4-cdd7-4011-937d-27b634a5c236")) {                    Plotly.newPlot(                        "d46154b4-cdd7-4011-937d-27b634a5c236",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[15.0,21.0,17.0,17.0,0.0,12.0,0.0,13.0,14.0,10.0,2.0,4.0,19.0,8.0,4.0,19.0,0.0,11.0,17.0,15.0,5.0,17.0,16.0,17.0,3.0,8.0,14.0,16.0,18.0,20.0,19.0,12.958333333333334,8.0,10.0,8.0,2.0,8.0,3.0,3.0,9.0,17.0,12.0,2.0,11.0,14.0,11.0,18.0,4.0,15.0,11.0,2.0,5.0,7.0,14.0,5.0,9.0,6.0,0.0,1.0,2.0,21.0,4.0,10.0,16.0,17.0,12.0,16.0,20.0,15.0,18.0,15.0,4.0,8.0,1.0,2.0,17.0,1.0,6.0,21.0,16.0,5.0,3.0,20.0,13.0,16.0,12.0,5.0,13.0,2.0,19.0,11.0,13.0,6.0,17.0,18.0,13.0,9.0,5.0,2.0,10.0,4.0,20.0,16.0,15.0,21.0,9.0,21.0,1.0,18.0,13.0,1.0,8.0,6.0,19.0,18.0,3.0,11.0,4.0,19.0,20.0,18.0,7.0,2.0,4.0,3.0,2.0,4.0,11.0,1.0,12.958333333333334,1.0,9.0,19.0,3.0,4.0,16.0,18.0,1.0,1.0,0.0,9.0,15.0,14.0,12.806451612903226,4.0,11.0,0.0,4.0,9.0,13.0,14.0,10.0,21.0,14.0,18.0,10.0,18.0,9.0,11.0,8.0,3.0,0.0,16.0,6.0,20.0,4.0,7.0,10.0,21.0,7.0,7.0,2.0,19.0,3.0,4.0,11.0,10.0,7.0,21.0,8.0,5.0,5.0,9.0,8.0,13.0,9.0,1.0,9.0,4.0,17.0,17.0,14.0,12.0,19.0,21.0,9.0,11.0,0.0,2.0,3.0,7.0,7.0,1.0,6.0,20.0,19.0,14.0,1.0,8.0,14.0,11.0,3.0,3.0,3.0,0.0,20.0,9.0,17.0,5.0,2.0,9.0,12.0,12.0,4.0,17.0,0.0,3.0,19.0,3.0,15.0,0.0,15.0,15.0,12.0,12.0,6.0,4.0,19.0,20.0,15.0,5.0,17.0,13.0,11.0,12.0,15.0,7.666666666666667,14.0,5.0,7.0,4.0,6.0,18.0,20.0,0.0,19.0,5.0,3.0,6.0,8.0,12.0,1.0,17.0,0.0,3.0,20.0,18.0,12.901639344262295,14.0,8.0,19.0,7.0,13.0,8.0,9.349514563106796,4.0,11.0,3.0,1.0,8.0,4.0,8.0,12.0,15.0,0.0,1.0,18.0,2.0,16.0,3.0,21.0,1.0,0.0,3.0,5.0,18.0,16.0,0.0,4.0,17.0,21.0,13.0,17.0,3.0,19.0,3.0,17.0,10.0,0.0,19.0,3.0,12.0,3.0,19.0,21.0,9.0,14.0,15.0,21.0,9.0,15.0,12.0,8.073170731707316,2.0,3.0,1.0,2.0,18.0,17.0,10.0,14.0,4.0,6.0,7.0,0.0,10.0,1.0,8.0,0.0,19.0,0.0,14.0,15.0,5.0,7.918918918918919,18.0,8.0,9.0,1.0,11.0,8.0,11.0,18.0,12.0,9.0,19.0,21.0,2.0,11.0,20.0,13.0,9.0,12.0,6.0,17.0,13.0,6.0,14.0,16.0,8.0,2.0,14.0,5.0,1.0,18.0,17.0,0.0,19.0,11.0,12.0,4.0,0.0,10.0,8.0,13.0,10.0,4.0,2.0,8.0,14.0,6.0,21.0,0.0,7.0,4.0,7.0,21.0,20.0,12.0,12.0,5.0,19.0,1.0,7.0,8.0,16.0,6.0,12.0,17.0,15.0,13.0,8.0,3.0,13.0,19.0,21.0,12.91304347826087,6.0,17.0,21.0,10.333333333333334,20.0,4.0 ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the AdaBoost Regressor model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="10da3fb4-926d-4bd7-920b-c62498e4af63" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10da3fb4-926d-4bd7-920b-c62498e4af63")) {                    Plotly.newPlot(                        "10da3fb4-926d-4bd7-920b-c62498e4af63",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell imports the RandomForestRegressor model from the scikit-learn library and initializes it with a specified number of estimators and max depth. It then trains the model on the training data.

# %%
from sklearn.ensemble import RandomForestRegressor
#rf = RandomForestRegressor(n_estimators=218,max_depth=2,min_samples_split=6,min_samples_leaf=3,max_features="log2")
rf = RandomForestRegressor(n_estimators=200, max_depth=7)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=200)

# %% [markdown]
# This cell uses the trained Random Forest Regressor model to make predictions on the test data and evaluates its performance using various regression metrics.

# %%
y_pred = rf.predict(x_test)
mse_rf = mean_squared_error(y_test,y_pred)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test,y_pred)
mae_rf = mean_absolute_error(y_test,y_pred)
ev_rf = explained_variance_score(y_test,y_pred)

print(f"\nModel: Random Forest Regressor")
print(f"R² Score: {r2_rf:.4f}")
print(f"Mean Absolute Error: {mae_rf:.4f}")
print(f"Explained Variance Score: {ev_rf:.4f}")
print(f"Root Mean Squared Error: {rmse_rf:.4f}")
# Out:
# Model: Random Forest Regressor
# R² Score: 0.9232
# Mean Absolute Error: 0.7051
# Explained Variance Score: 0.9239
# Root Mean Squared Error: 1.8032

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the Random Forest Regressor model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45cc2e31-2d59-4516-970b-34300f886ba7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45cc2e31-2d59-4516-970b-34300f886ba7")) {                    Plotly.newPlot(                        "45cc2e31-2d59-4516-970b-34300f886ba7",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[15.030442207238057,20.935859237324895,16.335377415960615,16.250229217009984,0.059060491013819154,12.349417168426564,0.059060491013819154,12.346848710592669,13.818570310522803,9.911764634876178,2.0460933507669723,4.044144039326742,19.013399803331527,7.761365829356528,4.0931492490280945,19.013399803331527,0.059060491013819154,8.408944959990942,17.38719315957988,15.030442207238057,5.35693078300561,16.311055907381032,16.0161702323859,16.90377530454489,3.0123393484182284,10.485976824863906,13.818570310522803,16.0161702323859,17.90842688792689,14.07077340092501,19.013399803331527,12.330977925212403,7.730516495896914,9.972622419963898,7.711207466925063,3.477497489012892,10.973240403591127,3.9774794208052957,3.3689389201495157,9.636328715505098,16.697700327069555,12.351394978905411,3.2008992133414496,10.885201497010712,13.695965029154356,10.390665205283867,16.557252030169064,4.007213116044717,15.030442207238057,9.683967011125315,7.944620933426005,5.581071260808024,6.947979659238831,13.818570310522803,5.263614654668516,9.105970596630959,6.05508135665843,0.14168549101381916,1.753556297106162,4.015617972382333,20.95811971611706,4.054597356527791,10.228027654076646,16.0161702323859,16.283127415960614,7.484794681054627,16.0161702323859,19.77471988801834,15.030442207238057,17.25230744376324,15.030442207238057,4.030708467638902,7.965526644886301,0.9896041467040678,2.9169120582967967,17.37410225048897,1.0217199361777523,5.992152552114237,20.831492183704114,16.0161702323859,5.552949581754881,3.349330173583409,11.962858662677736,10.446266124119845,16.0161702323859,12.185852890707121,5.356931024573819,12.37246262828305,2.2092853288605263,19.013399803331527,10.799058336763979,12.428667858454792,6.359698236557765,15.713486082725943,14.891888790414857,12.45188882868619,9.066831069166296,5.277115296912877,5.019327197666194,10.355720237725258,4.160651692820861,19.746397577378964,16.0161702323859,15.030442207238057,20.915770803232725,9.385475127240383,20.977215001447902,1.0032181040566017,17.46263887111203,12.42427065141099,1.000032053 ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the Random Forest Regressor model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e0fc9b2-de49-4a9a-84bb-f5711f91ef23" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e0fc9b2-de49-4a9a-84bb-f5711f91ef23")) {                    Plotly.newPlot(                        "4e0fc9b2-de49-4a9a-84bb-f5711f91ef23",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell imports the GradientBoostingRegressor model from the scikit-learn library and initializes it with specified parameters. It then trains the model on the training data.

# %%
from sklearn.ensemble import GradientBoostingRegressor
#gb = GradientBoostingRegressor(n_estimators=179,learning_rate=0.03021617089199866,max_depth=7,min_samples_split=8,min_samples_leaf=4,max_features="log2")
gb = GradientBoostingRegressor(n_estimators=200, learning_rate=0.5, max_depth=7)
gb.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.5, max_depth=7, n_estimators=200)

# %% [markdown]
# This cell uses the trained Gradient Boosting Regressor model to make predictions on the test data and evaluates its performance using various regression metrics.

# %%
y_pred = gb.predict(x_test)
mse_gb = mean_squared_error(y_test,y_pred)
rmse_gb = np.sqrt(mse_gb)
r2_gb = r2_score(y_test,y_pred)
mae_gb = mean_absolute_error(y_test,y_pred)
ev_gb = explained_variance_score(y_test,y_pred)

print(f"\nModel: Gradient Boosting Regressor")
print(f"R² Score: {r2_gb:.4f}")
print(f"Mean Absolute Error: {mae_gb:.4f}")
print(f"Explained Variance Score: {ev_gb:.4f}")
print(f"Root Mean Squared Error: {rmse_gb:.4f}")
# Out:
# Model: Gradient Boosting Regressor
# R² Score: 0.9457
# Mean Absolute Error: 0.4975
# Explained Variance Score: 0.9461
# Root Mean Squared Error: 1.5162

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the Gradient Boosting Regressor model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b16045f1-93a7-41df-ad2f-c01bcede27f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b16045f1-93a7-41df-ad2f-c01bcede27f1")) {                    Plotly.newPlot(                        "b16045f1-93a7-41df-ad2f-c01bcede27f1",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[15.003048942189622,20.99300885487324,16.58793637651885,17.103555487704327,0.011485670705923233,12.002165184251492,-0.04304473908801445,12.88087093040768,14.100071680642479,9.818536594983783,2.124844541588551,4.035209113531512,19.008803702140924,7.621488027848618,3.9806231229488924,19.326566062377342,-0.0194047270997825,7.828374498442299,16.613406739960492,14.957724080092197,5.103469434305306,17.02981520182155,15.947117448677723,16.933213022767248,3.0695845935112844,7.746400252050988,14.009140097296276,16.249810046589534,17.997616731059807,8.127593120533367,18.991896112403584,11.744430434222465,7.081987135537262,10.027976067735583,6.673765524958634,1.8603985862780645,7.9631169320266,3.0880064592250154,3.018408620150425,9.460071052721716,16.707043248141726,12.00518629556781,2.0867745406410183,11.032427891944586,13.53258279481051,10.676745050342413,18.563863024931752,3.8501589975244133,15.023669456789868,9.98583007044159,4.747279034674653,5.007910171334475,7.018356302640646,14.044262180719455,5.012361339501348,9.035956856782214,5.9950357724691345,-0.01782011111662714,1.0064088734516259,2.076289868850222,21.002062055642124,3.9786033202909024,9.797111447682067,15.971307921129261,17.403273433776672,10.96566242983259,16.158577733616482,20.093124486745932,15.010560615915947,20.16889909242125,14.995572193711311,3.9642558217840898,8.542361345143343,0.9319339075121807,1.350130796067874,17.199241263708046,0.9891089535752956,5.99748016271699,21.03280757508667,16.01969322711059,5.004734145597082,2.9686653048947034,11.999937225568802,13.419053536844228,16.01930774930976,12.034651002862788,5.002062611098668,12.331267174731332,2.996581876220879,19.031398403134865,10.905009740102065,13.198415789323587,6.26836108537197,17.294902624599462,17.874666180410053,12.72742519201744,9.004737019350522,4.842567172139853,2.1824446884479283,10.007374917374811,4.253686623035584,18.49099334467553,15.976168001676056,14.966074166349944,21.012397099876978,9.976565931175116,20.964901226726923,1.0305388898624261,19.10544274765175,13.538092271251895, ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the Gradient Boosting Regressor model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c4dc346e-4e36-4d8a-a6b8-856f0934d41a" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4dc346e-4e36-4d8a-a6b8-856f0934d41a")) {                    Plotly.newPlot(                        "c4dc346e-4e36-4d8a-a6b8-856f0934d41a",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell imports the XGBRegressor model from the xgboost library and initializes it with specified parameters. It then trains the model on the training data.

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(n_estimators=200,max_depth=7)
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# This cell uses the trained XGBoost Regressor model to make predictions on the test data and evaluates its performance using various regression metrics.

# %%
y_pred = xgb.predict(x_test)
mse_xgb = mean_squared_error(y_test,y_pred)
rmse_xgb = np.sqrt(mse_xgb)
r2_xgb = r2_score(y_test,y_pred)
mae_xgb = mean_absolute_error(y_test,y_pred)
ev_xgb = explained_variance_score(y_test,y_pred)

print(f"\nModel: XG Boosting Regressor")
print(f"R² Score: {r2_xgb:.4f}")
print(f"Mean Absolute Error: {mae_xgb:.4f}")
print(f"Explained Variance Score: {ev_xgb:.4f}")
print(f"Root Mean Squared Error: {rmse_xgb:.4f}")
# Out:
# Model: XG Boosting Regressor
# R² Score: 0.9560
# Mean Absolute Error: 0.4393
# Explained Variance Score: 0.9564
# Root Mean Squared Error: 1.3639

# %% [markdown]
# This cell generates and displays a scatter plot comparing the actual and predicted values from the XGBoost Regressor model.

# %%
fig = scatter_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="33707e85-c9d4-4951-a9d6-b539ebb0fb76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33707e85-c9d4-4951-a9d6-b539ebb0fb76")) {                    Plotly.newPlot(                        "33707e85-c9d4-4951-a9d6-b539ebb0fb76",                        [{"hovertemplate":"Actual Values=%{x}\u003cbr\u003ePredicted Values=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"xaxis":"x","y":[14.977716,20.995214,16.9274,17.021742,0.0041192407,11.973103,0.048504923,12.921727,14.014942,10.148861,1.9452007,3.9972374,19.000149,7.6919336,3.9870853,18.923677,-0.029576257,9.725569,16.918724,14.9917,5.020884,17.133526,15.970164,16.84845,2.9688797,7.42919,14.020052,15.951899,17.920607,14.218531,19.035185,12.898917,7.9174576,10.19295,7.5606728,2.8437607,9.566358,3.2067688,2.7820327,9.168811,16.938534,12.016192,1.8563281,11.222794,13.920179,11.487361,17.952896,3.9621847,15.013591,10.052803,5.504686,5.077232,7.0029707,14.083585,5.0135436,8.966288,5.96498,-0.0005060759,0.74575233,2.047642,21.03665,3.9967399,9.017059,15.986809,17.42246,11.48749,16.029442,20.043053,15.05072,17.99517,14.999651,3.9994752,7.8923564,0.9588906,2.1311216,16.95743,1.1697855,6.0193725,21.093876,15.992065,4.9441624,2.9800904,17.618032,12.805826,16.113628,12.075027,4.893648,12.875591,1.6612277,18.974232,11.524764,13.117974,6.474477,16.943962,17.424433,12.644355,9.802571,5.523362,2.2925096,10.310488,4.01194,19.76614,15.98156,14.989726,20.987715,9.108097,21.010294,1.0851603,19.315512,13.115194,0.963227,7.585891,5.938431,18.883196,18.300997,6.2850256,10.968478,4.0257344,19.226452,10.181973,17.272564,6.9893565,0.28480846,4.027444,2.937135,9.267806,3.9420192,8.480929,1.0925124,12.573397,1.0695459,9.032563,19.000628,3.2535143,4.0407896,16.019142,16.647173,0.9126473,0.94811153,0.0025797284,8.996891,14.983423,13.99484,12.750367,3.970076,10.4041815,0.052450113,4.055513,8.777616,13.344499,14.010516,10.137315,20.984669,13.989987,14.303367,11.519762,18.052593,9.063557,10.946529,7.34689,3.088353,-0.0055104606,15.9748,6.061446,20.196386,4.0098376,7.0327015,9.973621,21.01231,6.9936543,7.057579,2.0740685,18.96218,3.0680182,4.0077405,10.959873,10.050571,7.0539217,20.782127,6.9784784,5.540954,4.9201984,8.913301,8.378382,12.973058,8.946679,1.1624379,9.891076,4.1479306,16.9988,17.050003,13.97377,12.015219,18.508585,21.008455,9.116042,10.278639,0.009853017,1.7332985,2.794168,6.9410906,6.9991064,0.5892988,6.0533395,20.233845,18.814327,13.926872,1.0464,7.3636627, ...

# %% [markdown]
# This cell generates and displays a plot showing the actual and predicted values from the XGBoost Regressor model over their index.

# %%
fig = plot_actual_vs_predicted(y_test, y_pred)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52d7a468-b0f9-4e19-b572-688b06849aff" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52d7a468-b0f9-4e19-b572-688b06849aff")) {                    Plotly.newPlot(                        "52d7a468-b0f9-4e19-b572-688b06849aff",                        [{"marker":{"color":"blue","opacity":0.9,"size":10},"mode":"markers","name":"Actual","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889,2057,792,2095,275,254,306,1783,1189,759,168,668,184,414,1841,1463,111,742,2110,1271,618,2104,354,1964,1541,1033,746,1317,1830,817,1670,1788,408,1694,96,1461,422,1401,1845,2028,1001,741,1732,1075,1993,1337,1626,2133,247,73,552,1616,1194,2190,555,744,979,100,507,1936,1762,485,581,350,2131,719,807,1883,70,1699,1455,1347,303,1391,1090,420,599,1000,2024,1951,999,450,290,109,1834,930,67,478,1283,721,1861,281,788,1832,134,1078,519,1023,353,904,240,1851,1615,409,1043,1080,1553,332,1469,620,543,1868,135,1501,1855,360,538,611,856,1309,674,410,480,479,307,128,2022,289,1513,1605,1902,51,1897,1269,857,1341,1299,1228,764,962,218,1842,196,841,1244,1320,2051,2124,2121,367,2043,529,324,1040,383,1827,1760,1769,647,1175,943,1316,368,188,1575,780,259,1258,1270,1057,1950,48,905,630,1047,2091,632,120,282,211,231,1567,56,342,1749,2150,786,361,1117,1182,1891,1710,1556,233,976,298,1457,1538,1449,1494,1173,1178,1965,1840,925,44,1403,2185,1701,571,192,1151,1442,445,629,2176,1288,1836,1909,433,69,1583,985,2191,230,1980,2069,1177,1022,1726,1586,239,99,430,554,601,2081,998,1223,514,2013,124,1828,185,297,1061,65,1820,2005,1164,1405,1544,1036,426,707,1692,219,1380,1027,1552,212,2103,432,1651,1502,1821,1728,1303,527,1793,210,974,299,1746,829,1559,906,220,1192,237,986,1387,351,636,1402,1370,321,1460,1170,13,705,296,1073,772,471,1792,438,621,1825,1940,1232,1521,869,1044,2034,1592,948,1511,670,1448,2116,2175,406,2031,316,1005,105,2059,121,427,1181,387,993,1351,782,115,76,532,382,1187,1972,1791,548,1913,693,1680,2012,727,637,2109,1091,416,1778,1506,944,178,1105,1804,1590,867,2058,585,840,1879,798,2089,634,1932,1342,1508,1221,1809,1200,1322,63,1131,1124,2168,932,1054,1285,2067,1667,1963,1107,1719,1444,535,2040,205,528,978,1382,544,1956,1706,1302,588,23,1862,582,590,198,49,173,1865,1653,964,308,1307,617,787,59,71,1908,1958,482],"y":[15,21,17,17,0,12,0,13,14,10,2,4,19,8,4,19,0,11,17,15,5,17,16,17,3,8,14,16,18,20,19,13,8,10,8,2,8,3,3,9,17,12,2,11,14,11,18,4,15,11,2,5,7,14,5,9,6,0,1,2,21,4,10,16,17,18,16,20,15,18,15,4,8,1,2,17,1,6,21,16,5,3,20,13,16,12,5,13,2,19,11,13,6,17,18,13,9,5,2,10,4,20,16,15,21,9,21,1,18,13,1,8,6,19,18,3,11,4,19,20,18,7,2,4,3,2,4,11,1,13,1,9,19,3,4,16,18,1,1,0,9,15,14,13,4,11,0,4,9,13,14,10,21,14,18,18,18,9,11,8,3,0,16,6,20,4,7,10,21,7,7,2,19,3,4,11,10,7,21,8,5,5,9,8,13,9,1,9,4,17,17,14,12,19,21,9,11,0,2,3,7,7,1,6,20,19,14,1,8,14,11,3,3,3,0,20,9,17,5,2,9,12,12,4,17,0,3,19,3,15,0,15,15,12,12,6,4,19,20,15,5,17,13,11,12,15,18,14,5,7,4,6,18,20,0,19,5,3,6,8,12,1,17,0,3,20,18,13,14,8,19,7,13,8,11,4,11,3,1,20,4,8,12,15,0,1,18,2,16,3,21,1,0,3,5,18,16,0,4,17,21,13,17,3,19,3,17,10,0,19,3,12,3,19,21,9,14,15,21,9,15,12,20,2,3,1,2,18,17,18,14,4,6,7,0,10,1,8,0,19,0,14,15,5,5,18,8,9,1,11,8,11,18,12,9,19,21,2,11,20,13,9,12,6,17,13,6,14,16,8,2,14,5,1,18,17,0,19,11,12,4,0,10,8,13,10,4,2,8,14,6,21,0,7,4,7,21,20,12,12,5,19,1,7,8,16,6,12,17,15,13,8,3,13,19,21,13,6,17,21,13,20,4,13,13,11,20,11,4,16,19,9,21,14,2,20,20,6,6,18],"type":"scatter"},{"marker":{"color":"red","opacity":0.7},"mode":"markers","name":"Predicted","x":[1451,1334,1761,1735,1576,1110,1594,530,651,819,771,1878,915,2015,1876,937,1562,179,1723,1472,2167,1716,1646,1708,251,2009,602,1611,486,29,900,508,2082,889 ...

# %% [markdown]
# This cell creates a DataFrame to store the R² and RMSE scores of different regression models and then generates a grouped bar chart to visualize these scores using Plotly Express.

# %%
data = {
    'Model': ['Linear Regression', 'Logistic Regression', 'Knn Regression', 'Decision Tree', 'Random forest', 'AdaBoost', 'GradientBoost', 'XGboost'],
    'R2': [r2_lr, r2_lg, r2_knn, r2_dt, r2_rf, r2_ada, r2_gb, r2_xgb],
    'RMSE': [rmse_lr, rmse_lg, rmse_knn, rmse_dt, rmse_rf, rmse_ada, rmse_gb, rmse_xgb]
}
df1 = pd.DataFrame(data)

# Melt the DataFrame to long format for Plotly Express
df_melted = df1.melt(id_vars='Model', var_name='Metric', value_name='Score')

# Create the grouped bar chart
fig = px.bar(df_melted, x='Model', y='Score', color='Metric', barmode='group',
             title='Comparison of R2 and RMSE Scores for Different ML Models')

# To display the chart, you can use:
# fig.show()

# To save the chart to an HTML file, you can use:
# fig.write_html("model_scores_bar_chart.html")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="448e99b4-ca2f-473a-8e1d-046263811529" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("448e99b4-ca2f-473a-8e1d-046263811529")) {                    Plotly.newPlot(                        "448e99b4-ca2f-473a-8e1d-046263811529",                        [{"alignmentgroup":"True","hovertemplate":"Metric=R2\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"R2","offsetgroup":"R2","orientation":"v","showlegend":true,"textposition":"auto","x":["Linear Regression","Logistic Regression","Knn Regression","Decision Tree","Random forest","AdaBoost","GradientBoost","XGboost"],"xaxis":"x","y":[0.25634813007312396,0.8914218130999958,0.9583892636142672,0.9434820638896693,0.9231776365798924,0.9690997593198478,0.9456821947638384,0.9560460448265076],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=RMSE\u003cbr\u003eModel=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","showlegend":true,"textposition":"auto","x":["Linear Regression","Logistic Regression","Knn Regression","Decision Tree","Random forest","AdaBoost","GradientBoost","XGboost"],"xaxis":"x","y":[5.6101927407762995,2.1437011324936472,1.327075543006054,1.5466287958617346,1.8031704296939928,1.1435992867141318,1.5162263907744102,1.3639292229107283],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...

# %% [markdown]
# This cell creates a DataFrame `ml_models` to store the R² and RMSE scores for each trained machine learning model.

# %%
data = {
    'Model': ['Linear Regression', 'Logistic Regression', 'Knn Regression', 'Decision Tree', 'Random forest', 'AdaBoost', 'GradientBoost', 'XGboost'],
    'R^2': [r2_lr, r2_lg, r2_knn, r2_dt, r2_rf, r2_ada, r2_gb, r2_xgb],
    'RMSE': [rmse_lr, rmse_lg, rmse_knn, rmse_dt, rmse_rf, rmse_ada, rmse_gb, rmse_xgb]
}
ml_models = pd.DataFrame(data)

# %% [markdown]
# This cell generates a horizontal bar chart using Plotly to visualize the R² scores of the different models, highlighting the highest R² value and showing a trend line.

# %%
colors = px.colors.sequential.Viridis[:len(ml_models)]

# Create Plotly figure
fig = go.Figure()

# Horizontal bar chart
fig.add_trace(go.Bar(
    y=ml_models['Model'],
    x=ml_models['R^2'],
    orientation='h',
    marker=dict(color=colors),
    name="R² Scores",
    text=[f"{val:.2f}" for val in ml_models['R^2']],
    textposition="outside"
))

# Trend line (scatter)
x_vals = ml_models['R^2']
y_vals = ml_models['Model']
fig.add_trace(go.Scatter(
    x=x_vals,
    y=y_vals,
    mode='lines+markers',
    name='Trend Line',
    line=dict(color='blue', width=2),
    marker=dict(size=8, color='blue')
))

# Highlight highest value
max_idx = ml_models['R^2'].idxmax()
fig.add_trace(go.Scatter(
    x=[ml_models['R^2'][max_idx]],
    y=[ml_models['Model'][max_idx]],
    mode='markers',
    name='Highest Value',
    marker=dict(size=12, color='red', line=dict(width=1, color='black'))
))

# Layout customization
fig.update_layout(
    title="R² of Different Models",
    xaxis_title="R²",
    yaxis_title="Model",
    template="plotly_white",
    height = 800,
    legend=dict(
        x=0.5,
        y=1.12,
        xanchor='center',
        yanchor='bottom',
        orientation='h'  # place legend horizontally above chart
    ),
    xaxis=dict(showgrid=True, gridwidth=0.5, gridcolor='lightgray')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d85b6a5-5fb4-4059-9d4f-4d545d034845" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d85b6a5-5fb4-4059-9d4f-4d545d034845")) {                    Plotly.newPlot(                        "6d85b6a5-5fb4-4059-9d4f-4d545d034845",                        [{"marker":{"color":["#440154","#482878","#3e4989","#31688e","#26828e","#1f9e89","#35b779","#6ece58"]},"name":"R² Scores","orientation":"h","text":["0.26","0.89","0.96","0.94","0.92","0.97","0.95","0.96"],"textposition":"outside","x":[0.25634813007312396,0.8914218130999958,0.9583892636142672,0.9434820638896693,0.9231776365798924,0.9690997593198478,0.9456821947638384,0.9560460448265076],"y":["Linear Regression","Logistic Regression","Knn Regression","Decision Tree","Random forest","AdaBoost","GradientBoost","XGboost"],"type":"bar"},{"line":{"color":"blue","width":2},"marker":{"color":"blue","size":8},"mode":"lines+markers","name":"Trend Line","x":[0.25634813007312396,0.8914218130999958,0.9583892636142672,0.9434820638896693,0.9231776365798924,0.9690997593198478,0.9456821947638384,0.9560460448265076],"y":["Linear Regression","Logistic Regression","Knn Regression","Decision Tree","Random forest","AdaBoost","GradientBoost","XGboost"],"type":"scatter"},{"marker":{"color":"red","line":{"color":"black","width":1},"size":12},"mode":"markers","name":"Highest Value","x":[0.9690997593198478],"y":["AdaBoost"],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"hi ...

# %% [markdown]
# This cell sorts the `ml_models` DataFrame by RMSE in descending order and generates a horizontal bar chart using Plotly to visualize the RMSE scores, highlighting the highest RMSE value and showing a trend line.

# %%
ml_models = ml_models.sort_values(by='RMSE', ascending=False)

fig = go.Figure()

# Add the horizontal bar trace
# The custom color palette is handled by providing a list of colors
fig.add_trace(go.Bar(
    y=ml_models['Model'],
    x=ml_models['RMSE'],
    orientation='h',
    name='RMSE',
    marker_color=['#440154', '#472f7d', '#3e4989', '#31688e', '#26828e']
))

# Find the highest RMSE value and its corresponding model
max_rmse = ml_models['RMSE'].max()
max_model = ml_models['Model'][ml_models['RMSE'].idxmax()]

# Add a scatter trace to highlight the highest value
fig.add_trace(go.Scatter(
    x=[max_rmse],
    y=[max_model],
    mode='markers',
    marker=dict(
        color='red',
        size=12,
        line=dict(width=2, color='Black')
    ),
    name='Highest Value'
))

# Add a trend line, which is a scatter trace with lines+markers mode
fig.add_trace(go.Scatter(
    x=ml_models['RMSE'],
    y=ml_models['Model'],
    mode='lines+markers',
    name='Trend Line',
    line=dict(color='blue', width=2),
    marker=dict(size=8)
))

# Add value labels on the bars as annotations
for index, row in ml_models.iterrows():
    fig.add_annotation(
        x=row['RMSE'],
        y=row['Model'],
        text=f'{row["RMSE"]:.2f}',
        showarrow=False,
        xshift=40,  # Adjust horizontal position of the text
        yshift=0,
        font=dict(color='black', size=10),
        xref="x",
        yref="y"
    )

# Update layout to add title, labels, and customize the plot
fig.update_layout(
    title='RMSE of Different Models',
    xaxis_title='RMSE',
    yaxis_title='Model',
    yaxis=dict(categoryorder='total descending', gridcolor='lightgrey', zerolinecolor='lightgrey'),
    showlegend=True,
    height=800,
    legend=dict(
        x=0.5,
        y=1.12,
        xanchor='center',
        yanchor='bottom',
        orientation='h'  # place legend horizontally above chart
    ),
    plot_bgcolor='white',
    xaxis=dict(gridcolor='lightgrey', zerolinecolor='lightgrey')
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="652caa32-b23c-4ec4-b322-f6e7a2260500" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("652caa32-b23c-4ec4-b322-f6e7a2260500")) {                    Plotly.newPlot(                        "652caa32-b23c-4ec4-b322-f6e7a2260500",                        [{"marker":{"color":["#440154","#472f7d","#3e4989","#31688e","#26828e"]},"name":"RMSE","orientation":"h","x":[5.6101927407762995,2.1437011324936472,1.8031704296939928,1.5466287958617346,1.5162263907744102,1.3639292229107283,1.327075543006054,1.1435992867141318],"y":["Linear Regression","Logistic Regression","Random forest","Decision Tree","GradientBoost","XGboost","Knn Regression","AdaBoost"],"type":"bar"},{"marker":{"color":"red","line":{"color":"Black","width":2},"size":12},"mode":"markers","name":"Highest Value","x":[5.6101927407762995],"y":["Linear Regression"],"type":"scatter"},{"line":{"color":"blue","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Trend Line","x":[5.6101927407762995,2.1437011324936472,1.8031704296939928,1.5466287958617346,1.5162263907744102,1.3639292229107283,1.327075543006054,1.1435992867141318],"y":["Linear Regression","Logistic Regression","Random forest","Decision Tree","GradientBoost","XGboost","Knn Regression","AdaBoost"],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...
